# %% [markdown]
# # 启用交互式 widget 后端

# %%
# %matplotlib widget

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# 🔹 blit=True 和 blit=False 的区别
#
# blit=True	只重绘更新的部分，更高效，但 不支持 set_xlim() 和 set_ylim() 这种会改变 Axes 结构的操作
#
# blit=False	每一帧都会重绘整个图像，性能较低，但适用于所有 matplotlib 版本，支持 set_xlim() 和 set_ylim()。

# %%
fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = ax.plot([], [], 'ro')

def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def animate(i):
    xdata.append(i)
    ydata.append(np.sin(i))
    ln.set_data(xdata, ydata)   # 覆盖之前的数据
    return ln,

ani = FuncAnimation(
    fig,
    animate,
    frames=np.linspace(0, 2*np.pi, 128),
    init_func=init,
    blit=True
)
plt.show()

# %% [markdown]
# # Multi-Line Plot Animation

# %%
fig, axes = plt.subplots(1,2)
xdata, ydata1, ydata2 = [], [], []
ln1,  = axes[0].plot([], [], 'ro')
ln2, = axes[1].plot([], [], 'bo')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def init():
    axes[0].set_xlim(0, 2*np.pi)
    axes[0].set_ylim(-1, 1)
    axes[1].set_xlim(0, 2*np.pi)
    axes[1].set_ylim(-1, 1)
    return ln1, ln2,

def animate(i):
    xdata.append(i)
    ydata1.append(np.sin(i))
    ydata2.append(np.cos(i))
    ln1.set_data(xdata, ydata1) 
    ln2.set_data(xdata, ydata2)
    return ln1, ln2,

ani = FuncAnimation(
    fig,
    animate,
    frames=np.linspace(0, 2*np.pi, 128),
    init_func=init,
    blit=False
)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
